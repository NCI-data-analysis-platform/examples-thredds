# %% [markdown]
# # CMIP6 and CMIP5 comparison AU future projection
#
#
#
# The following material uses Coupled Model Intercomparison Project (CMIP6) collections. The CMIP6 terms of use are found[here](https://pcmdi.llnl.gov/CMIP6/TermsOfUse/TermsOfUse6-1.html). For more information on the collection, please click [here]( https://geonetwork.nci.org.au/geonetwork/srv/eng/catalog.search#/metadata/f6600_2266_8675_3563).
#
# We will show the different temperature trend shown among the 6 members of the ssp126 experiment of CNRM-CM6-1 model in CMIP6 archive.
#
# <div class="alert alert-warning">
# <b>NOTE:</b> You need to run this notebook in VDI so as to access data through file system.
# </div>
#
# ---

# %% [markdown]
# - Authors:  virtual research environment team at NCI
# - Keywords: CMIP6, xarray, Clef
# - Software: Python, Clef
# - Create Date: 2020-May-29
# - Key updates:
# - Lineage/Reference: none

# %% [markdown]
# ### Prerequisite
#
# To run this notebook on Gadi/VDI, or on your local computer. The following modules are needed:
#
# * Python (with xarray installed)
#
# To be able to access Clef tool on Gadi, you need to be a member of the project:
# * hh5
#
# You also need to be a member of the following data project to access the data or through [NCI's data service](http://dapds00.nci.org.au/thredds/catalog.html) if the data is published:
# * oi10
#
# You can request to join the project through [NCI's user account management system](https://my.nci.org.au).

# %% [markdown]
# ### Load libraries

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from os import path

# %% [markdown]
# ### Use Clef to check data availability

# %%
# !module use /g/data3/hh5/public/modules
# !module load conda/analysis3
# !clef cmip6 --help
# Out:
# /bin/sh: command substitution: line 1: syntax error near unexpected token `('
# /bin/sh: command substitution: line 1: `cat <(echo $OLD_LOADEDMODULES | tr ':' '\n') <(echo $LOADEDMODULES | tr ':' '\n') | sort | uniq -c | awk '$1==1{print $2}')'
# Usage: clef cmip6 [OPTIONS] [QUERY]...
#
#   Search ESGF and local database for CMIP6 files Constraints can be
#   specified multiple times, in which case they are combined using OR:  -v
#   tas -v tasmin will return anything matching variable = 'tas' or variable =
#   'tasmin'. The --latest flag will check ESGF for the latest version
#   available, this is the default behaviour
#
# Options:
#   -mip, --activity [AerChemMIP|C4MIP|CDRMIP|CFMIP|CMIP|CORDEX|DAMIP|DCPP|DynVarMIP|FAFMIP|GMMIP|GeoMIP|HighResMIP|ISMIP6|LS3MIP|LUMIP|OMIP|PAMIP|PMIP|RFMIP|SIMIP|ScenarioMIP|VIACSAB|VolMIP]
#   -e, --experiment x              CMIP6 experiment, list of available depends
#                                   on activity
#   --source_type [AER|AGCM|AOGCM|BGC|CHEM|ISM|LAND|OGCM|RAD|SLAB]
#   -t, --table x                   CMIP6 CMOR table: Amon, SIday, Oday ...
#   -m, --model, --source_id x      CMIP6 model id: GFDL-AM4, CNRM-CM6-1 ...
#   -v, --variable x                CMIP6 variable name as in filenames
#   -mi, --member TEXT              CMIP6 member id: <sub-exp-id>-r#i#p#f#
#   -g, --grid, --grid_label TEXT   CMIP6 grid label: i.e. gn for the model
#                                   native grid
#   -nr, --resolution, --nominal_resolution TEXT
#                                   Approximate resolution: '250 km', pass in
#                                   quotes
#   --frequency [1hr|1hrCM|1hrPt|3hr|3hrPt|6hr|6hrPt|day|dec|fx|mon|monC|monPt|subhrPt|yr|yrPt]
#   --realm [atmos|ocean|land|landIce|seaIce|aerosol|atmosChem|ocnBgchem]
#   -se, --sub_experiment_id TEXT   Only available for hindcast and forecast
#                                   experiments: sYYYY
#   -vl, --variant_label TEXT       Indicates a model variant: r#i#p#f#
#   --and [variable_id|experiment_id|table_id|realm|frequency|member_id|source_id|source_type|activity_id|grib_label|nominal_resolution|sub_experiment_id]
#                                   Attributes for which we want to add AND
#                                   filter, i.e. `--and variable_id` to apply to
#                                   variable values
#   --institution TEXT              Modelling group institution id: IPSL, NOAA-
#                                   GFDL ...
#   --cf_standard_name TEXT         CF variable standard_name, use instead of
#                                   variable constraint
#   --format [file|dataset]         Return output for datasets (default) or
#                                   individual files
#   --latest / --all-versions       Return only the latest version or all of
#                                   them. Default: --latest
#   --replica / --no-replica        Return both original files and replicas.
#                                   Default: --no-replica
#   --distrib / --no-distrib        Distribute search across all ESGF nodes.
#                                   Default: --distrib
#   --csv / --no-csv                Send output to csv file including extra
#                                   information. Default: --no-csv
#   --stats / --no-stats            Write summary of query results, works only
#                                   with --local option. Default: --no-stats
#   --debug / --no-debug            Show debug output. Default: --no-debug
#   --help                          Show this message and exit.

# %%
# !clef cmip6 --activity CMIP \
           --table  Amon          \
           --grid   gr            \
           --variable   pr       \
           --experiment  historical
# Out:
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/historical/r4i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1-HR/historical/r1i1p1f2/Amon/pr/gr/v20191021/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r9i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r9i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/E3SM-Project/E3SM-1-0/historical/r1i1p1f1/Amon/pr/gr/v20190730/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r3i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r2i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/E3SM-Project/E3SM-1-0/historical/r1i1p1f1/Amon/pr/gr/v20190913/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/historical/r3i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/historical/r2i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r3i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg-LR/historical/r1i1p1f1/Amon/pr/gr/v20200217/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r7i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r4i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r2i1p1f2/Amon/pr/gr/v20181126/
# /g/data/oi10/replicas/CMIP6/CMIP/E3SM-Project/E3SM-1-1/historical/r1i1p1f1/Amon/pr/gr/v20191211/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r1i1p1f2/Amon/pr/gr/v20180917/
# /g/data/oi10/replicas/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg/historical/r1i1p1f1/Amon/pr/gr/v20200225/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r8i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r6i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r7i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/historical/r1i1p1f2/Amon/pr/gr/v20181206/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r6i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r4i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/THU/CIESM/historical/r1i1p1f1/Amon/pr/gr/v20200417/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r5i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-ESM2-1/historical/r5i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r5i1p1f2/Amon/pr/gr/v20190125/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r8i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r1i1p1f1/Amon/pr/gr/v20200310/
# /g/data/oi10/replicas/CMIP6/CMIP/CAS/FGOALS-f3-L/historical/r1i1p1f1/Amon/pr/gr/v20190927/
# /g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r10i1p1f1/Amon/pr/gr/v20180803/
# /g/data/oi10/replicas/CMIP6/CMIP/E3SM-Project/E3SM-1-1-ECA/historical/r1i1p1f1/Amon/pr/gr/v20200127/
# /g/data/oi10/replicas/CMIP6/CMIP/CNRM-CERFACS/CNRM-CM6-1/historical/r10i1p1f2/Amon/pr/gr/v20190125/
#
# Available on ESGF but not locally:
# CMIP6.CMIP.CAS.FGOALS-f3-L.historical.r2i1p1f1.Amon.pr.gr.v20190927
# CMIP6.CMIP.CAS.FGOALS-f3-L.historical.r3i1p1f1.Amon.pr.gr.v20190927
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r11i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r12i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r13i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r14i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r15i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r16i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r17i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r18i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r19i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r20i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r21i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r22i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r24i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r25i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r26i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r27i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r28i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r29i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-CM6-1.historical.r30i1p1f2.Amon.pr.gr.v20191004
# CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r10i1p1f2.Amon.pr.gr.v20200117
# CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r11i1p1f2.Amon.pr.gr.v20200408
# CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r7i1p1f2.Amon.pr.gr.v20200117
# CMIP6.CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.r8i1p1f2.Amon.pr.gr.v20200117
# CMIP6.CMIP.NIMS-KMA.KACE-1-0-G.historical.r3i1p1f1.Amon.pr.gr.v20190919
# CMIP6.CMIP.THU.CIESM.historical.r2i1p1f1.Amon.pr.gr.v20200417
# CMIP6.CMIP.THU.CIESM.historical.r3i1p1f1.Amon.pr.gr.v20200417

# %%
# !clef cmip5 --table  Amon          \
            --variable   pr        \
            --experiment  historical
# Out:
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r10i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r10i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r1i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r1i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r2i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r2i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r3i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r3i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r4i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r4i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r5i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r5i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r6i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r6i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r7i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r7i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r8i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r8i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r9i1p1/v20120207/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanCM4/historical/mon/atmos/Amon/r9i1p1/v20120612/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanESM2/historical/mon/atmos/Amon/r2i1p1/v20120718/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanESM2/historical/mon/atmos/Amon/r3i1p1/v20120718/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanESM2/historical/mon/atmos/Amon/r4i1p1/v20120718/pr/
# /g/data/al33/replicas/CMIP5/combined/CCCma/CanESM2/historical/mon/atmos/Amon/r5i1p1/v20120718/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CESM/historical/mon/atmos/Amon/r1i1p1/v20120907/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CESM/historical/mon/atmos/Amon/r1i1p1/v20170725/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CM/historical/mon/atmos/Amon/r1i1p1/v20121008/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CM/historical/mon/atmos/Amon/r1i1p1/v20170725/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CMS/historical/mon/atmos/Amon/r1i1p1/v20120717/pr/
# /g/data/al33/replicas/CMIP5/combined/CMCC/CMCC-CMS/historical/mon/atmos/Amon/r1i1p1/v20170725/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5-2/historical/mon/atmos/Amon/r1i1p1/v20130401/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r10i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r1i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r2i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r3i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r4i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/CNRM-CERFACS/CNRM-CM5/historical/mon/atmos/Amon/r5i1p1/v20110901/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-CESS/FGOALS-g2/historical/mon/atmos/Amon/r4i1p1/v20161204/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-CESS/FGOALS-g2/historical/mon/atmos/Amon/r5i1p1/v1/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-CESS/FGOALS-g2/historical/mon/atmos/Amon/r5i1p1/v20161204/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-IAP/FGOALS-s2/historical/mon/atmos/Amon/r1i1p1/v20161204/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-IAP/FGOALS-s2/historical/mon/atmos/Amon/r2i1p1/v1/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-IAP/FGOALS-s2/historical/mon/atmos/Amon/r2i1p1/v20161204/pr/
# /g/data/al33/replicas/CMIP5/combined/LASG-IAP/FGOALS-s2/historical/mon/atmos/Amon/r3i1p1/v1/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC-ESM-CHEM/historical/mon/atmos/Amon/r1i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC-ESM/historical/mon/atmos/Amon/r1i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC-ESM/historical/mon/atmos/Amon/r2i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC-ESM/historical/mon/atmos/Amon/r3i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC4h/historical/mon/atmos/Amon/r1i1p1/v20120628/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC4h/historical/mon/atmos/Amon/r2i1p1/v20120628/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC4h/historical/mon/atmos/Amon/r3i1p1/v20120628/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC5/historical/mon/atmos/Amon/r1i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC5/historical/mon/atmos/Amon/r2i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC5/historical/mon/atmos/Amon/r3i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC5/historical/mon/atmos/Amon/r4i1p1/v20121221/pr/
# /g/data/al33/replicas/CMIP5/combined/MIROC/MIROC5/historical/mon/atmos/Amon/r5i1p1/v20120710/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r10i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r1i1p1/v20110823/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r2i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r3i1p1/v20110905/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r4i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r5i1p1/v20110905/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r6i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r7i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r8i1p1/v20110905/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadCM3/historical/mon/atmos/Amon/r9i1p1/v20110728/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-CC/historical/mon/atmos/Amon/r1i1p1/v20110927/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-CC/historical/mon/atmos/Amon/r2i1p1/v20111129/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-CC/historical/mon/atmos/Amon/r3i1p1/v20111208/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-ES/historical/mon/atmos/Amon/r1i1p1/v20120928/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-ES/historical/mon/atmos/Amon/r2i1p1/v20110418/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-ES/historical/mon/atmos/Amon/r3i1p1/v20110418/pr/
# /g/data/al33/replicas/CMIP5/combined/MOHC/HadGEM2-ES/historical/mon/atmos/Amon/r4i1p1/v20110418/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-LR/historical/mon/atmos/Amon/r1i1p1/v20120315/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-LR/historical/mon/atmos/Amon/r2i1p1/v20120315/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-LR/historical/mon/atmos/Amon/r3i1p1/v20120315/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-MR/historical/mon/atmos/Amon/r1i1p1/v20120503/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-MR/historical/mon/atmos/Amon/r2i1p1/v20120503/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-MR/historical/mon/atmos/Amon/r3i1p1/v20120503/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-P/historical/mon/atmos/Amon/r1i1p1/v20120315/pr/
# /g/data/al33/replicas/CMIP5/combined/MPI-M/MPI-ESM-P/historical/mon/atmos/Amon/r2i1p1/v20120315/pr/
# /g/data/al33/replicas/CMIP5/combined/MRI/MRI-CGCM3/historical/mon/atmos/Amon/r1i1p1/v20120701/pr/
# /g/data/al33/replicas/CMIP5/combined/MRI/MRI-CGCM3/historical/mon/atmos/Amon/r2i1p1/v20120701/pr/
# /g/data/al33/replicas/CMIP5/combined/MRI/MRI-CGCM3/historical/mon/atmos/Amon/r3i1p1/v20120701/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r2i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r3i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r4i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r5i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r6i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r7i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r8i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM2p1/historical/mon/atmos/Amon/r9i1p1/v20110601/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r1i1p1/v20120227/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r2i1p1/v20120227/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r3i1p1/v20120227/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r4i1p1/v20120227/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-CM3/historical/mon/atmos/Amon/r5i1p1/v20120227/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-ESM2G/historical/mon/atmos/Amon/r1i1p1/v20120412/pr/
# /g/data/al33/replicas/CMIP5/combined/NOAA-GFDL/GFDL-ESM2M/historical/mon/atmos/Amon/r1i1p1/v20111228/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-0/historical/mon/atmos/Amon/r1i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-0/historical/mon/atmos/Amon/r2i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-0/historical/mon/atmos/Amon/r3i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-3/historical/mon/atmos/Amon/r1i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-3/historical/mon/atmos/Amon/r2i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-BOM/ACCESS1-3/historical/mon/atmos/Amon/r3i1p1/latest/pr/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r10i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r1i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r2i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r3i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r4i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r5i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r6i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r7i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r8i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/CSIRO-QCCCE/CSIRO-Mk3-6-0/historical/mon/atmos/Amon/r9i1p1/files/pr_20110518/
# /g/data1/rr3/publications/CMIP5/output1/UNSW/CSIRO-Mk3L-1-2/historical/mon/atmos/Amon/r1i2p1/files/pr_20170728/
# /g/data1/rr3/publications/CMIP5/output1/UNSW/CSIRO-Mk3L-1-2/historical/mon/atmos/Amon/r2i2p1/files/pr_20170728/
# /g/data1/rr3/publications/CMIP5/output1/UNSW/CSIRO-Mk3L-1-2/historical/mon/atmos/Amon/r3i2p1/files/pr_20170728/
# Available on ESGF but not locally:
# cmip5.output1.ICHEC.EC-EARTH.historical.mon.atmos.Amon.r14i1p1.v20171115 pr

# %%
# !ls /g/data1b/oi10/replicas/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1/ssp126/r2i1p1f2/Amon/tas/gr/v20190410/
# Out:
# tas_Amon_CNRM-CM6-1_ssp126_r2i1p1f2_gr_201501-210012.nc

# %% [markdown]
# ### Use xarray to open ensemble data files

# %%
! ls /g/data/oi10/replicas/CMIP6/CMIP
# Out:
# AS-RCEC  CCCma	       E3SM-Project	    IPSL   NASA-GISS  NUIST
# AWI	 CCCR-IITM     EC-Earth-Consortium  MIROC  NCAR       SNU
# BCC	 CNRM-CERFACS  FIO-QLNM		    MOHC   NCC	      THU
# CAMS	 CSIRO	       HAMMOZ-Consortium    MPI-M  NIMS-KMA   UA
# CAS	 CSIRO-ARCCSS  INM		    MRI    NOAA-GFDL

# %%
#read a cmip6 example data
file='/g/data/oi10/replicas/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/historical/r1i1p1f1/Amon/pr/gr/v20180803/pr_Amon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc'
if path.exists(file):
    ds_cmip6=xr.open_dataset(file)
ds_cmip6
# Out:
# <xarray.Dataset>
# Dimensions:      (axis_nbounds: 2, lat: 143, lon: 144, time: 1980)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73239 -87.46479 ... 88.73239 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time         (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     pr           (time, lat, lon) float32 ...
# Attributes:
#     Conventions:            CF-1.7 CMIP-6.2
#     creation_date:          2018-07-11T07:36:41Z
#     tracking_id:            hdl:21.14100/f63dbc41-c629-41a4-8646-c3423a1f1379
#     description:            CMIP6 historical
#     title:                  IPSL-CM6A-LR model output prepared for CMIP6 / CM...
#     activity_id:            CMIP
#     contact:                ipsl-cmip6@listes.ipsl.fr
#     data_specs_version:     01.00.21
#     dr2xml_version:         1.11
#     experiment_id:          historical
#     experiment:             all-forcing simulation of the recent past
#     external_variables:     areacella
#     forcing_index:          1
#     frequency:              mon
#     grid:                   LMDZ grid
#     grid_label:             gr
#     nominal_resolution:     250 km
#     initialization_index:   1
#     institution_id:         IPSL
#     institution:            Institut Pierre Simon Laplace, Paris 75252, France
#     license:                CMIP6 model data produced by IPSL is licensed und...
#     mip_era:                CMIP6
#     parent_experiment_id:   piControl
#     parent_mip_era:         CMIP6
#     parent_activity_id:     CMIP
#     parent_source_id:       IPSL-CM6A-LR
#     parent_time_units:      days since 1850-01-01 00:00:00
#     branch_method:          standard
#     branch_time_in_parent:  21914.0
#     branch_time_in_child:   0.0
#     physics_index:          1
#     product:                model-output
#     realm:                  atmos
#     source:                 IPSL-CM6A-LR (2017):  atmos: LMDZ (NPv6, N96; 144...
#     source_id:              IPSL-CM6A-LR
#     source_type:            AOGCM BGC
#     sub_experiment_id:      none
#     sub_experiment:         none
#     table_id:               Amon
#     variable_id:            pr
#     EXPID:                  historical
#     CMIP6_CV_version:       cv=6.2.3.5-2-g63b123e
#     dr2xml_md5sum:          f1e40c1fc5d8281f865f72fbf4e38f9d
#     model_version:          6.1.5
#     parent_variant_label:   r1i1p1f1
#     name:                   /ccc/work/cont003/gencmip6/p86caub/IGCM_OUT/IPSLC...
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.IPSL.IPSL-CM...
#     variant_label:          r1i1p1f1
#     realization_index:      1
#     history:                Sat Dec  1 12:16:37 2018: ncatted -O -a realizati...
#     NCO:                    "4.6.0"

# %%
# read a cmip5 example data
file='/g/data/al33/replicas/CMIP5/combined/IPSL/IPSL-CM5A-LR/historical/mon/atmos/Amon/r1i1p1/v20110406/pr/pr_Amon_IPSL-CM5A-LR_historical_r1i1p1_185001-200512.nc'
if path.exists(file):
    ds_cmip5=xr.open_dataset(file)
ds_cmip5
# Out:
# <xarray.Dataset>
# Dimensions:    (bnds: 2, lat: 96, lon: 96, time: 1872)
# Coordinates:
#   * time       (time) object 1850-01-16 12:00:00 ... 2005-12-16 12:00:00
#   * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#   * lon        (lon) float64 0.0 3.75 7.5 11.25 15.0 ... 345.0 348.8 352.5 356.2
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) object ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     pr         (time, lat, lon) float32 ...
# Attributes:
#     institution:            IPSL (Institut Pierre Simon Laplace, Paris, France)
#     institute_id:           IPSL
#     experiment_id:          historical
#     source:                 IPSL-CM5A-LR (2010) : atmos : LMDZ4 (LMDZ4_v5, 96...
#     model_id:               IPSL-CM5A-LR
#     forcing:                Nat,Ant,GHG,SA,Oz,LU,SS,Ds,BC,MD,OC,AA
#     parent_experiment_id:   piControl
#     parent_experiment_rip:  r1i1p1
#     branch_time:            1850.0
#     contact:                ipsl-cmip5 _at_ ipsl.jussieu.fr Data manager : Se...
#     comment:                This 20th century simulation include natural and ...
#     references:             Model documentation and further reference availab...
#     initialization_method:  1
#     physics_version:        1
#     tracking_id:            ca1f7e92-cda0-44c2-a30b-882b082b2148
#     product:                output
#     experiment:             historical
#     frequency:              mon
#     creation_date:          2011-02-23T17:54:51Z
#     history:                2011-02-23T17:54:51Z CMOR rewrote data to comply ...
#     Conventions:            CF-1.4
#     project_id:             CMIP5
#     table_id:               Table Amon (31 January 2011) 53b766a395ac41696af4...
#     title:                  IPSL-CM5A-LR model output prepared for CMIP5 hist...
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.5.1

# %%
#read observation data --era5
ds_tp = xr.open_mfdataset('/g/data/ub4/era5/netcdf/surface/tp/*/tp_era5_global_*.nc',combine='nested', concat_dim='time')

# %%
ds_tp

# %%
# data processing: daily-monthly, rename variable and coordinates names
ds_tp_mon = ds_tp.resample(time='M').mean().rename({'latitude':'lat'}).rename({'longitude':'lon'}).rename({'tp':'pr'})
ds_tp_mon

# %%
#data interptation--remap ds_tp_mon and ds_cmip5 to the same resolution as ds_cmip6
new_lon =ds_cmip6.lon
new_lat =ds_cmip6.lat
ds_tp_mon_i=ds_tp_mon.interp(lat=new_lat, lon=new_lon)
ds_cmip5_i=ds_cmip5.interp(lat=new_lat, lon=new_lon)
ds_cmip5_i

# %%
#calculate precipitation bias for the average period of 1995-2005
pr_bias_cmip5=(ds_cmip5_i.sel(time=slice('1995','2005'))).mean(dim='time') - (ds_tp_mon_i.sel(time=slice('1995','2005'))).mean(dim='time')
pr_bias_cmip6=(ds_cmip6.sel(time=slice('1995','2005'))).mean(dim='time') - (ds_tp_mon_i.sel(time=slice('1995','2005'))).mean(dim='time')

# %%
pr_bias_cmip5['pr'].sel(lat=slice(-15,-45),lon=slice(110,156)).plot()

# %%
pr_bias_cmip6['pr'].sel(lat=slice(-15,-45),lon=slice(110,156)).plot()
